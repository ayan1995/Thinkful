# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans, MiniBatchKMeans, MeanShift, estimate_bandwidth, SpectralClustering
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import cdist
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import cycle
# %matplotlib inline

# %% [markdown]
# ### How can I identify similar Marathon performances?

# %%
df = pd.read_csv('results.csv')

# Drop row in city where there's a null value
df = df.dropna(subset=['city'])

# Replace values that represent null
df = df.replace('-', np.nan)

# Convert types to numeric
df[['10k', '25k', '35k', '30k', '5k', 'half', '20k', '40k']] = df[['10k', '25k', '35k', '30k', '5k', 'half', '20k', '40k']].apply(pd.to_numeric)

# Impute null with means
df = df.fillna(df.mean())

# %%
df.head()
# Out:
#      10k                name  division    25k gender  age  official bib  \
# 0  17.37  Yamamoto, Hiroyuki         8  47.67      M   47     85.25  W1
# 1  32.58        Jeptoo, Rita         1  82.43      F   33    138.95  F1
# 2  16.62   Van Dyk, Ernst F.         1  45.80      M   41     80.60  W2
# 3  32.57        Dibaba, Mare         3  82.43      F   24    140.58  F2
# 4  17.12      Hokinoue, Kota         2  46.37      M   40     81.23  W3
#
#    genderdiv  ctz   ...    overall  pace  state    30k     5k   half    20k  \
# 0          8  NaN   ...          8  3.27    NaN  59.18   8.02  39.72  37.65
# 1          1  NaN   ...         21  5.30    NaN  99.33  16.22  69.47  65.83
# 2          1  NaN   ...          1  3.08    NaN  56.45   7.75  38.03  36.10
# 3          3  NaN   ...         27  5.37    NaN  99.33  16.20  69.47  65.83
# 4          2  NaN   ...          2  3.10    NaN  57.03   8.02  38.60  36.58
#
#    country            city     40k
# 0      JPN         Fukuoka   80.43
# 1      KEN         Eldoret  132.10
# 2      RSA           Paarl   76.10
# 3      ETH            Shoa  132.95
# 4      JPN  Nogata Fukuoka   76.72
#
# [5 rows x 21 columns]

# %%
# One-Hot encoding
df['gender'] = pd.get_dummies(df.gender, drop_first=True)

# Create features
features = df.drop(['state', 'ctz', 'name', 'city', 'country', 'bib', 'gender', 'division', 'genderdiv', 'overall', 'age', 'official'], 1)

# Define the features and the outcome.
X = features.iloc[:, :9]
y = features.iloc[:, 8]

# %%
features.head()
# Out:
#      10k    25k     35k  pace    30k     5k   half    20k     40k
# 0  17.37  47.67   71.40  3.27  59.18   8.02  39.72  37.65   80.43
# 1  32.58  82.43  116.37  5.30  99.33  16.22  69.47  65.83  132.10
# 2  16.62  45.80   67.42  3.08  56.45   7.75  38.03  36.10   76.10
# 3  32.57  82.43  116.37  5.37  99.33  16.20  69.47  65.83  132.95
# 4  17.12  46.37   67.83  3.10  57.03   8.02  38.60  36.58   76.72

# %%
#sns.pairplot(features)

# %%
# Create PCAs for all distance interval
x_pca = PCA(2).fit_transform(features)
dfx_pca = pd.DataFrame(data=x_pca, columns=['PCA1', 'PCA2'])
x_pca = dfx_pca.values

dfx_pca.head()
# Out:
#          PCA1       PCA2
# 0 -259.492392  15.151135
# 1 -162.990446   2.648166
# 2 -266.647139  14.782877
# 3 -162.486957   3.174566
# 4 -265.340899  14.298981

# %%
#sns.pairplot(dfx_pca)

# %%
# Create list of distortions for each K value
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(x_pca)
    kmeanModel.fit(x_pca)
    distortions.append(sum(np.min(cdist(x_pca, kmeanModel.cluster_centers_, 'euclidean'), axis=1))/ X.shape[0])

# plot the Elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortions')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
# Calculate predicted values.
y_pred = KMeans(n_clusters=3, random_state=42).fit_predict(x_pca)

# Plot the solution.
plt.scatter(x_pca[:, 0], x_pca[:, 1], c=y_pred)
plt.show()

# %%
# Labels
# Calculate predicted values.
kmeans = KMeans(n_clusters=3, random_state=42).fit(x_pca)

kmeans.labels_

features['Labels'] = kmeans.labels_

# %%
# Value counts
features.Labels.value_counts()
# Out:
# 1    14911
# 0    11897
# 2     5175
# Name: Labels, dtype: int64

# %%
features.head()
# Out:
#      10k    25k     35k  pace    30k     5k   half    20k     40k  Labels
# 0  17.37  47.67   71.40  3.27  59.18   8.02  39.72  37.65   80.43       1
# 1  32.58  82.43  116.37  5.30  99.33  16.22  69.47  65.83  132.10       1
# 2  16.62  45.80   67.42  3.08  56.45   7.75  38.03  36.10   76.10       1
# 3  32.57  82.43  116.37  5.37  99.33  16.20  69.47  65.83  132.95       1
# 4  17.12  46.37   67.83  3.10  57.03   8.02  38.60  36.58   76.72       1

# %%
# Assign independent and dependent variables
x = features.drop(columns=['Labels'])
y = features['Labels']

# Create array of x
x = x.values

# %%
# Plot clusters over scatter plot of features
plt.figure(figsize=(8,8))
plt.scatter(x[:,0], x[:,1], c=y_pred)
plt.show()

# %%
# Division vs 40k
plt.figure(figsize=(8,8))
sns.relplot(x='division', y='40k', data=df, hue=y_pred)
plt.xlabel('Division')
plt.ylabel('40k')
plt.title('Division vs. 40k')
plt.show()

# %%
# Genderdiv vs. 40k
plt.figure(figsize=(8,8))
sns.relplot(x='genderdiv', y='40k', data=df, hue=y_pred)
plt.xlabel('genderdiv')
plt.ylabel('40k')
plt.title('genderdiv vs. 40k')
plt.show()

# %%
# Assign labels to df
df['Labels'] = kmeans.labels_

# Create dataframe sorted by labels
labels = df.groupby(['Labels']).mean().sort_values(['40k'])

# Create data frame sorting by top 10 countries
country_top_10 = df.groupby(['country']).mean().sort_values(by=['40k']).head(10)

# %%
for x in labels.columns:
    plt.figure(figsize=(8,8))
    labels[x].plot.bar()
    plt.title(x)
    plt.show()

# %%
# Mean 40k time per top 10 countries
for x in country_top_10.columns:
    plt.figure(figsize=(8,8))
    plt.bar(country_top_10.index, country_top_10[x])
    plt.xlabel('country')
    plt.ylabel(x)
    plt.title(x)
    plt.show()

# %%
labels.head()
# Out:
#               10k     division         25k    gender        age    official  \
# Labels
# 1       44.626385  1199.417477  113.050657  0.677553  40.011133  200.744379
# 0       54.576348  2158.206439  140.689260  0.435572  45.159704  256.602823
# 2       66.082926  3526.600386  176.587916  0.450628  42.980290  333.467942
#
#            genderdiv         35k       overall       pace         30k  \
# Labels
# 1        4199.442827  163.081681   7482.386560   7.664745  137.423071
# 0       10088.707826  207.155152  20742.624695   9.794987  172.783826
# 2       14465.050435  270.506861  29266.211594  12.723486  223.916132
#
#                5k        half         20k         40k
# Labels
# 1       22.311233   94.897893   89.923266  189.236958
# 0       27.200584  117.223567  111.011265  241.794044
# 2       32.357960  147.196478  139.021145  314.170857

# %%
df.head()
# Out:
#      10k                name  division    25k  gender  age  official bib  \
# 0  17.37  Yamamoto, Hiroyuki         8  47.67       1   47     85.25  W1
# 1  32.58        Jeptoo, Rita         1  82.43       0   33    138.95  F1
# 2  16.62   Van Dyk, Ernst F.         1  45.80       1   41     80.60  W2
# 3  32.57        Dibaba, Mare         3  82.43       0   24    140.58  F2
# 4  17.12      Hokinoue, Kota         2  46.37       1   40     81.23  W3
#
#    genderdiv  ctz  ...    pace  state    30k     5k   half    20k  country  \
# 0          8  NaN  ...    3.27    NaN  59.18   8.02  39.72  37.65      JPN
# 1          1  NaN  ...    5.30    NaN  99.33  16.22  69.47  65.83      KEN
# 2          1  NaN  ...    3.08    NaN  56.45   7.75  38.03  36.10      RSA
# 3          3  NaN  ...    5.37    NaN  99.33  16.20  69.47  65.83      ETH
# 4          2  NaN  ...    3.10    NaN  57.03   8.02  38.60  36.58      JPN
#
#              city     40k Labels
# 0         Fukuoka   80.43      1
# 1         Eldoret  132.10      1
# 2           Paarl   76.10      1
# 3            Shoa  132.95      1
# 4  Nogata Fukuoka   76.72      1
#
# [5 rows x 22 columns]

# %%
features.head()
# Out:
#      10k    25k     35k  pace    30k     5k   half    20k     40k  Labels
# 0  17.37  47.67   71.40  3.27  59.18   8.02  39.72  37.65   80.43       1
# 1  32.58  82.43  116.37  5.30  99.33  16.22  69.47  65.83  132.10       1
# 2  16.62  45.80   67.42  3.08  56.45   7.75  38.03  36.10   76.10       1
# 3  32.57  82.43  116.37  5.37  99.33  16.20  69.47  65.83  132.95       1
# 4  17.12  46.37   67.83  3.10  57.03   8.02  38.60  36.58   76.72       1

# %%
country_top_10
# Out:
#                10k     division         25k    gender        age    official  \
# country
# THA      18.470000    14.000000   49.450000  1.000000  34.500000   91.200000
# MAR      30.530000    10.000000   76.970000  1.000000  33.000000  132.720000
# ETH      32.296667     6.333333   81.953333  0.166667  26.500000  140.646667
# BLR      33.230000     6.000000   83.400000  0.000000  26.000000  141.480000
# KEN      34.022500   178.833333   86.620000  0.500000  31.000000  151.455833
# UKR      39.636667  1415.666667  101.416667  1.000000  31.000000  181.173333
# CAY      41.450000  2548.000000  108.120000  1.000000  39.000000  192.500000
# GUA      44.321333  1038.266667  112.288000  0.466667  38.400000  196.702667
# HUN      43.306667  1489.000000  111.010000  1.000000  41.666667  198.693333
# TRI      46.430000   638.000000  115.330000  0.000000  30.000000  198.330000
#
#            genderdiv         35k      overall      pace         30k  \
# country
# THA        14.000000   72.400000    14.500000  3.485000   60.670000
# MAR        10.000000  109.150000    10.000000  5.070000   92.600000
# ETH         6.333333  115.961667    34.833333  5.373333   98.833333
# BLR         6.000000  117.650000    34.000000  5.400000  100.580000
# KEN       925.250000  124.015000  2135.583333  5.782500  104.920833
# UKR      4168.666667  148.406667  6319.333333  6.916667  124.383333
# CAY      4222.000000  157.650000  4682.000000  7.350000  132.820000
# GUA      2474.400000  160.648000  6575.000000  7.510667  135.930667
# HUN      4941.666667  160.223333  7342.000000  7.580000  135.393333
# TRI       799.000000  163.180000  6007.000000  7.570000  138.800000
#
#                 5k       half        20k         40k    Labels
# country
# THA       8.830000  41.360000  39.210000   82.005000  1.000000
# MAR      15.180000  64.880000  61.630000  125.230000  1.000000
# ETH      16.035000  69.030000  65.426667  132.850000  1.000000
# BLR      16.470000  70.250000  66.570000  134.200000  1.000000
# KEN      16.868333  72.837500  69.054167  143.082500  0.916667
# UKR      19.900000  84.613333  80.130000  171.356667  0.666667
# CAY      20.720000  90.370000  85.550000  181.600000  1.000000
# GUA      22.240667  94.366000  89.432000  185.560667  1.000000
# HUN      21.576667  92.900000  87.950000  186.466667  0.666667
# TRI      23.280000  97.400000  92.500000  187.520000  1.000000

# %%
top_10 = df.sort_values(by ='40k', ascending=True).head(40)
top_10
# Out:
#        10k                         name  division    25k  gender  age  \
# 2    16.62            Van Dyk, Ernst F.         1  45.80       1   41
# 8    17.12            Soejima, Masazumi         3  46.37       1   43
# 4    17.12               Hokinoue, Kota         2  46.37       1   40
# 6    17.65               Hug, Marcel E.         4  47.67       1   28
# 16   17.13                Madera, Jordi         5  47.45       1   34
# 30   18.75               George, Joshua         6  49.15       1   30
# 18   18.17             Hamerlak, Tomasz         7  49.15       1   38
# 0    17.37           Yamamoto, Hiroyuki         8  47.67       1   47
# 40   17.67               Senbeta, James         9  48.55       1   27
# 56   18.17              Wahoram, Prawat        18  49.15       1   33
# 23   18.17      Botello Jimenez, Rafael        12  49.15       1   35
# 12   18.13         Lemeunier, Denis Sr.        11  49.17       1   49
# 58   18.77                  Tana, Rawat        10  49.75       1   36
# 14   17.12             Cassidy, Josh R.        13  48.88       1   29
# 24   18.30              Filteau, Michel        14  50.33       1   47
# 27   18.78                 Kim, Gyu Dae        15  50.33       1   30
# 43   18.77               Bleakney, Adam        16  52.07       1   38
# 124  20.65            McFadden, Tatyana         1  54.18       0   25
# 36   19.37               Gordian, Aaron        17  54.20       1   49
# 53   20.22               Siemann, Brian        19  55.67       1   24
# 61   20.22                  Qi, Ji Dong        22  55.68       1   19
# 66   19.73                Cao, De Cheng        20  54.18       1   21
# 82   21.07               Dodson, Travis        21  56.47       1   28
# 133  19.75             Tsuchida, Wakako         2  54.88       0   39
# 33   18.30  Puigbo Verdaguer, Roger Sr.        24  52.90       1   36
# 51   19.37              Kozarek, Robert        23  54.32       1   25
# 141  20.65            Scaroni, Susannah         3  55.75       0   22
# 48   20.17                  Park, Peter        25  56.28       1   36
# 139  20.55               Schar, Manuela         4  55.40       0   29
# 65   21.13                   Li, Lai Zu        26  57.87       1   26
# 136  20.65                Woods, Shelly         5  55.73       0   27
# 143  20.65                   Roy, Diane         6  57.47       0   43
# 38   20.68              Ray, Bradley F.        30  58.28       1   45
# 59   21.47             Pulido, Jose Sr.        28  58.30       1   33
# 73   25.15        McCallister, Kacey Z.        29  61.87       1   27
# 76   21.27                 Vick, Wes B.        27  59.32       1   33
# 130  21.07           Reilly, Shirley S.         7  58.43       0   28
# 70   21.60               Sanz, Santiago         1  60.13       1   33
# 90   22.65              Martin, Raymond         2  61.75       1   20
# 95   21.55             Doak, Patrick A.        31  60.82       1   46
#
#      official   bib  genderdiv  ctz  ...    pace  state    30k     5k   half  \
# 2       80.60    W2          1  NaN  ...    3.08    NaN  56.45   7.75  38.03
# 8       81.23    W6          3  NaN  ...    3.10    NaN  57.03   8.00  38.60
# 4       81.23    W3          2  NaN  ...    3.10    NaN  57.03   8.02  38.60
# 6       84.65    W4          4  NaN  ...    3.23    NaN  58.60   8.38  39.72
# 16      84.70    W9          5  NaN  ...    3.23    NaN  58.73   8.02  39.12
# 30      84.82   W15          6  NaN  ...    3.25     IL  59.92   8.93  41.18
# 18      84.88   W10          7  NaN  ...    3.25    NaN  59.92   8.67  41.20
# 0       85.25    W1          8  NaN  ...    3.27    NaN  59.18   8.02  39.72
# 40      85.38   W19          9  NaN  ...    3.27     IL  59.77   8.38  40.45
# 56      95.50   W25         18  NaN  ...    3.65    NaN  60.17   8.68  41.20
# 23      86.95   W12         12  NaN  ...    3.32    NaN  60.87   8.68  41.20
# 12      86.95    W7         11  NaN  ...    3.32    NaN  60.85   8.40  41.18
# 58      86.90   W26         10  NaN  ...    3.32    NaN  61.17   8.98  41.52
# 14      87.40    W8         13  NaN  ...    3.35     ON  60.82   8.02  40.20
# 24      89.40   W13         14  NaN  ...    3.42     QC  62.33   8.67  41.80
# 27      89.52   W14         15  KOR  ...    3.42     IL  62.72   8.98  41.82
# 43      92.87   W20         16  NaN  ...    3.55     IL  64.87   8.92  43.00
# 124     95.10  W101          1  NaN  ...    3.63     IL  66.48  10.12  45.43
# 36      95.28   W17         17  MEX  ...    3.65     AZ  66.62   8.93  44.82
# 53      96.53   W24         19  NaN  ...    3.68     IL  68.17   9.40  46.23
# 61      96.60   W28         22  NaN  ...    3.70    NaN  68.17   9.33  46.23
# 66      96.53   W30         20  NaN  ...    3.68    NaN  67.45   9.25  44.72
# 82      96.57   W36         21  NaN  ...    3.68     IL  68.65  10.15  47.13
# 133     97.40  W105          2  NaN  ...    3.72    NaN  68.18   9.25  45.42
# 33      98.42   W16         24  NaN  ...    3.77    NaN  67.12   8.68  43.17
# 51      98.13   W23         23  NaN  ...    3.75     IL  68.53   9.12  45.27
# 141     98.55  W108          3  NaN  ...    3.77     IL  68.93  10.12  46.33
# 48      99.00   W22         25  NaN  ...    3.78     IL  69.53   9.25  46.70
# 139     99.65  W107          4  NaN  ...    3.82    NaN  69.10   9.72  46.07
# 65     100.62   W29         26  NaN  ...    3.85    NaN  70.95   9.97  48.65
# 136    101.70  W106          5  NaN  ...    3.88    NaN  69.42  10.10  46.35
# 143    103.67  W109          6  NaN  ...    3.97     QC  71.78   9.65  47.32
# 38     104.15   W18         30  NaN  ...    3.98     CO  72.95   9.40  48.35
# 59     104.08   W27         28  MEX  ...    3.98     GA  72.97  10.08  48.77
# 73     104.13   W33         29  NaN  ...    3.98     OR  74.83   9.72  52.23
# 76     104.02   W34         27  NaN  ...    3.98     ON  73.72   9.77  49.27
# 130    104.57  W104          7  NaN  ...    4.00     AZ  72.98  10.12  48.68
# 70     106.20   W32         31  NaN  ...    4.07    NaN  74.35  10.17  49.93
# 90     108.48   W41         32  NaN  ...    4.15     IL  75.83  10.67  51.57
# 95     109.00   W43         33  NaN  ...    4.17     MA  75.83   9.93  50.43
#
#        20k  country                     city     40k Labels
# 2    36.10      RSA                    Paarl   76.10      1
# 8    36.60      JPN                  Isahaya   76.70      1
# 4    36.58      JPN           Nogata Fukuoka   76.72      1
# 6    37.65      SUI               Neuenkirch   79.83      1
# 16   36.98      ESP           Les Franquesas   79.92      1
# 30   39.08      USA                Champaign   80.18      1
# 18   39.05      POL                   Bystra   80.18      1
# 0    37.65      JPN                  Fukuoka   80.43      1
# 40   38.33      USA                Champaign   80.62      1
# 56   39.05      THA                  Bangkok   81.83      1
# 23   39.05      ESP                  Manlleu   82.17      1
# 12   39.03      FRA                    Taule   82.17      1
# 58   39.37      THA                  Bangkok   82.18      1
# 14   38.02      CAN               Port Elgin   82.38      1
# 24   39.63      CAN         St-Jean Baptiste   84.48      1
# 27   39.65      USA                Champaign   84.75      1
# 43   40.83      USA                Champaign   87.70      1
# 124  43.12      USA                Champaign   89.87      1
# 36   42.47      USA                  Phoenix   90.07      1
# 53   43.78      USA                    Savoy   91.63      1
# 61   43.80      CHN                Liao Ning   91.65      1
# 66   42.32      CHN                Liao Ning   91.65      1
# 82   44.77      USA                Champaign   91.68      1
# 133  43.15      JPN          Tama City Tokyo   92.07      1
# 33   40.73      ESP  Sant Julia De Vilatorta   92.87      1
# 51   43.02      USA                Champaign   93.03      1
# 141  43.95      USA                   Urbana   93.08      1
# 48   44.32      USA                Champaign   93.65      1
# 139  43.67      SUI                   Kriens   94.22      1
# 65   46.15      CHN                Liao ning   95.12      1
# 136  43.93      GBR        Lytham - St Annes   95.80      1
# 143  44.87      CAN               Sherbrooke   97.73      1
# 38   45.88      USA                 Loveland   98.48      1
# 59   46.33      USA             Clarkesville   98.48      1
# 73   49.77      USA                 Monmouth   98.58      1
# 76   46.72      CAN                  Toronto   98.65      1
# 130  46.13      USA                   Tucson   98.73      1
# 70   47.28      ESP                 Albatera  100.28      1
# 90   48.82      USA                Champaign  102.50      1
# 95   47.82      USA                 Carlisle  103.03      1
#
# [40 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['10k', 'name', 'division', '25k', 'gender', 'age', 'official', 'bib',
#        'genderdiv', 'ctz', '35k', 'overall', 'pace', 'state', '30k', '5k',
#        'half', '20k', 'country', 'city', '40k', 'Labels'],
#       dtype='object')
