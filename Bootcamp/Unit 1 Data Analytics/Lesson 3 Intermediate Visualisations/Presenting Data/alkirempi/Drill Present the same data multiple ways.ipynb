# %% [markdown]
# https://www.kaggle.com/ophi/mpi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
# %matplotlib inline

# %%
df_national = pd.read_csv('MPI_national.csv')
df_subnational = pd.read_csv('MPI_subnational.csv')

# %%
df_subnational
# Out:
#     ISO country code      Country  Sub-national region        World region  \
# 0                AFG  Afghanistan           Badakhshan          South Asia
# 1                AFG  Afghanistan              Badghis          South Asia
# 2                AFG  Afghanistan              Baghlan          South Asia
# 3                AFG  Afghanistan                Balkh          South Asia
# 4                AFG  Afghanistan               Bamyan          South Asia
# 5                AFG  Afghanistan             Daykundi          South Asia
# 6                AFG  Afghanistan                Farah          South Asia
# 7                AFG  Afghanistan               Faryab          South Asia
# 8                AFG  Afghanistan               Ghazni          South Asia
# 9                AFG  Afghanistan                 Ghor          South Asia
# 10               AFG  Afghanistan              Helmand          South Asia
# ...

# %% [markdown]
# ## Choose one variable and plot that variable four different ways.

# %%
df_ubran_deprivation = df_national.head(20)
df_urban_deprivation = df_ubran_deprivation[(['Country', 'Intensity of Deprivation Urban'])]

ax = sns.barplot(data = df_urban_deprivation.reset_index(), x = 'index', y = 'Intensity of Deprivation Urban')
plt.show()

ax = sns.pointplot(data = df_urban_deprivation.reset_index(), x = 'index', y = 'Intensity of Deprivation Urban', join = False)
plt.show()

ax = sns.distplot(df_ubran_deprivation['Intensity of Deprivation Urban'])
plt.show()

ax = sns.lineplot(data = df_urban_deprivation.reset_index(), x = 'index', y = 'Intensity of Deprivation Urban')
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Choose two continuous variables, and plot them three different ways.

# %%
headcount_vs_Intensity = df_national[(['Headcount Ratio Urban', 'Intensity of Deprivation Urban'])]
x = headcount_vs_Intensity['Headcount Ratio Urban']
y = headcount_vs_Intensity['Intensity of Deprivation Urban']

ax = sns.regplot(x, y)
plt.show()

ax = sns.lineplot(x, y)
plt.show()

ax = sns.lmplot('Headcount Ratio Urban', 'Intensity of Deprivation Urban', data = headcount_vs_Intensity)
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
df_ubran_deprivation = df_national.head(10)
df_urban_deprivation = df_ubran_deprivation[(['Country', 'Intensity of Deprivation Urban'])]
x = df_urban_deprivation['Country']
y = df_urban_deprivation['Intensity of Deprivation Urban']

ax = sns.barplot(x, y)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

ax = sns.pointplot(x, y, join=False)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

ax = sns.scatterplot(x, y)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

Afghanisan_urban_deprivation = df_subnational[df_subnational['Country'] == 'Afghanistan']
Afghanisan_urban_deprivation = Afghanisan_urban_deprivation['Intensity of deprivation Regional']
y = Afghanisan_urban_deprivation 


ax = sns.distplot(y)
ax.set_title('Distribution of Intensity of deprivation Regional for Afghanistan')
plt.show()

Afghanisan_urban_deprivation = df_subnational[(['Intensity of deprivation Regional', 'Country'])]
Afghanisan_urban_deprivation = Afghanisan_urban_deprivation[(Afghanisan_urban_deprivation['Country']=='Afghanistan')|(Afghanisan_urban_deprivation['Country']=='Yemen')]

ax = sns.catplot(x = 'Country', y = 'Intensity of deprivation Regional', data = Afghanisan_urban_deprivation )
plt.show()

ax = sns.catplot(x = 'Country', y = 'Intensity of deprivation Regional', kind='box', data = Afghanisan_urban_deprivation )
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Challenge:
#
# As an optional challenge, find a dataset with at least four continuous variables and one categorical variable. Create one master plot that gives insight into the variables and their interrelationships, including:
#
# - Probability distributions
# - Bivariate relationships
# - Whether the distributions or the relationships vary across groups
#
# Accompany your plot with a written description of what you see.

# %%
# Pairplot

df_national = df_national.head(40)

sns.pairplot(df_national)

# %% [markdown]
# The pairplot above visualizes the bivariate relationships between 5 different continuous variables for different countries. It shows us the probability distibution for each variable as well. We can easily point out the variables that have a clear relationship such as MPI Urban and Headcount Ratio Urban. Looking around we see that this realtionship is consistent between MPI and Headcount ratio whether it's rural or urban. A cross relationship between urban and rural also exist between the Headcount ratio and MPI, so that relationship is worth a further investigation.
