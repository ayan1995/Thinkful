# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')

# %% [markdown]
# # Clean and Format Data

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...         V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...    0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...    0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...    0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...    0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...    0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
# Explore Amount as there seems to be lots of variance and outliers
plt.figure(figsize=(10,8))
sns.distplot(df['Amount'])
plt.title('Distribution plot of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10,8))
sns.boxplot(df['Amount'])
plt.title('Boxplot of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Amount Variable
#
# After reviewing this variable, it may be appropriate to apply a log + 1 transformation to normalize the distribution of the amount Variable

# %%
# Explore Time
plt.figure(figsize=(10,8))
sns.distplot(df['Time'])
plt.title('Distribution plot of time')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10,8))
sns.boxplot(df['Time'])
plt.title('Boxplot of Time')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Time Variable
#
# The distribution of the time variable seems to have twin peaks. Research online and ask mentor about what to do about it. How or if to correct it.

# %% [markdown]
# ### V Variable
# - V1 is extremely negatively skewed

# %% [markdown]
# ## Observations
#
# 1. Amount variable is positively skewed with median around 0. A log+1 transformation is apporpriate.
# 2. Some sort of correction should be applied to the double peaks in the time variable.
# 3. Consider removing V1 from features since its extre negative skew and the relatively normal skews of the other Vs.
# 4. Fix Class Imbalance

# %% [markdown]
# # Feature Selection and Engineering

# %%
# Create feature of log of Amount plus 1 to normalize
features = pd.DataFrame()
features = df.drop(columns = ['V1', 'Amount'])
features['log_Amount'] = np.log(df['Amount']+1)

# Visualize distrubtion

plt.figure(figsize=(10,8))
sns.distplot(features['log_Amount'])
plt.title('Distribution plot of Log Amount')
plt.xlabel('Log Amount')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10,8))
sns.boxplot(features['log_Amount'])
plt.title('Boxplot of Log Amount')
plt.xlabel('Log Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Remove Outliers
q75, q25 = np.percentile(features.log_Amount, [75, 25])
iqr = q75 - q25

min = q25 - (iqr*1.5)
max = q75 + (iqr*1.5)

i = 'log_Amount'
 
plt.figure(figsize=(10,8))
plt.subplot(211)
plt.xlim(features[i].min(), features[i].max()*1.1)
plt.axvline(x=min)
plt.axvline(x=max)
 
ax = features[i].plot(kind='kde')
 
plt.subplot(212)
plt.xlim(features[i].min(), features[i].max()*1.1)
sns.boxplot(x=features[i])
plt.axvline(x=min)
plt.axvline(x=max)

# %%
# Remove Outliers
features = features[(features['log_Amount'] > (q25 - 1.5 * iqr)) &
            (features['log_Amount'] < (q75 + 1.5 * iqr))]

# Visualize Transformed Data 
plt.figure(figsize=(10,8))
plt.subplot(211)
sns.distplot(features['log_Amount'])
plt.show()

plt.figure(figsize=(10,8))
plt.subplot(212)
sns.boxplot(features['log_Amount'])
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
features.describe()
# Out:
#                 Time             V2             V3             V4  \
# count  284562.000000  284562.000000  284562.000000  284562.000000
# mean    94816.286384       0.011754       0.005475      -0.002911
# std     47489.680612       1.580230       1.499639       1.410482
# min         0.000000     -72.715728     -33.680984      -5.683171
# 25%     54212.000000      -0.596389      -0.886713      -0.849283
# 50%     84692.500000       0.066546       0.181102      -0.021142
# 75%    139324.000000       0.804291       1.027901       0.740970
# max    172792.000000      22.057729       9.382558      16.491217
#
#                   V5             V6             V7             V8  \
# count  284562.000000  284562.000000  284562.000000  284562.000000
# mean        0.008170      -0.004618      -0.009194       0.002058
# std         1.316372       1.306403       1.154222       1.188890
# min       -23.669726     -26.160506     -43.557242     -73.216718
# ...

# %% [markdown]
# # Balancing Class Preprocessing
#
# ### Randomly Under-sample

# %%
print(features[features.Class==0].shape)
print(features[features.Class==1].shape)
# Out:
# (284070, 30)
# (492, 30)

# %%
# Random Downsample

#Separate Classes
features_majority = features[features['Class']==0]
features_minority = features[features['Class']==1]

# Downsample Majority Class
features_majority_downsampled = features_majority.sample(n=9348, random_state=123)

# Upsample Minority Class
features_minority_upsampled = features_minority.sample(replace=True, n=984, random_state=123)

# Combine Minority Class with downsampled Majority Class
features = pd.concat([features_majority_downsampled, features_minority_upsampled])

# Display new class counts
features.Class.value_counts()
# Out:
# 0    9348
# 1     984
# Name: Class, dtype: int64
